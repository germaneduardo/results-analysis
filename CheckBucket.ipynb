# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv("test.csv")

# %%
test.head(5)
# Out:
#      idn  label  signature  Feature0  Feature1  Feature2  Feature3  Feature4  \
# 0  48573      0         77 -1.850475  0.361369 -0.580956 -2.079547 -1.950560
# 1  38669      0         77  1.911770 -0.327196 -1.585676  0.123748  0.885472
# 2  43732      0         77 -1.718398  2.088887 -1.585554 -0.986786  0.559565
# 3  39918      0         77 -0.154995  0.123311 -0.088081 -2.945289  1.205804
# 4  34000      0         77 -0.099739  0.651486 -0.306392 -0.838063  1.169913
#
#    Feature5  Feature6    ...      Feature18  Feature19  Feature20  Feature21  \
# 0 -0.093064 -0.538232    ...       0.041925  -0.369259   0.436861   1.006500
# 1  0.887378 -0.040491    ...      -0.722561  -0.218401  -0.179714  -0.341588
# 2 -0.022607  0.302180    ...       0.554169  -0.057521   0.464392   1.250306
# 3  0.539357  0.615720    ...      -2.025011  -0.134442   0.651884   1.926172
# 4  0.395820  1.297045    ...       0.278696  -0.156188  -0.282639  -0.346803
#
# ...

# %%
# %matplotlib inline 
import seaborn as sns
sns.set(style='darkgrid')

# %%
cols_ignore = ["idn", "label", "signature"]
cols_to_select = [col for col in test.columns if col not in (cols_ignore)]

# %%
g = sns.pairplot(test,  vars = cols_to_select[0:10], hue="label", diag_kind = "kde")

# %%
test.count()

# %%
g = sns.pairplot(test,  vars = cols_to_select[10:20], hue="label", diag_kind = "kde")

# %%
g = sns.pairplot(test,  vars = cols_to_select[20:28], hue="label", diag_kind = "kde")

# %%
from matplotlib import pyplot
sns.lmplot(x="Feature0", y="Feature1", data=test, hue= "signature", size=9 , aspect = 3.0, fit_reg=False)

# %%
test.groupby("label").count()
# Out:
#         idn  signature  Feature0  Feature1  Feature2  Feature3  Feature4  \
# label
# 0      1002       1002      1002      1002      1002      1002      1002
# 1         4          4         4         4         4         4         4
#
#        Feature5  Feature6  Feature7    ...      Feature18  Feature19  \
# label                                  ...
# 0          1002      1002      1002    ...           1002       1002
# 1             4         4         4    ...              4          4
#
#        Feature20  Feature21  Feature22  Feature23  Feature24  Feature25  \
# label
# 0           1002       1002       1002       1002       1002       1002
# 1              4          4          4          4          4          4
#
#        Feature26  Feature27
# label
# 0           1002       1002
# 1              4          4
#
# [2 rows x 30 columns]

# %%
test[test.idn==39140]
# Out:
#        idn  label  signature  Feature0  Feature1  Feature2  Feature3  \
# 194  39140      0         77 -1.321029  0.413102 -1.491904 -0.100063
#
#      Feature4  Feature5  Feature6    ...      Feature18  Feature19  Feature20  \
# 194  0.550467 -0.805935  0.129881    ...       0.737675  -0.304851   -0.22214
#
#      Feature21  Feature22  Feature23  Feature24  Feature25  Feature26  \
# 194  -0.256705   0.253846  -0.669204  -0.267249  -0.103381  -0.253165
#
#      Feature27
# 194  -0.384558
#
# [1 rows x 31 columns]
